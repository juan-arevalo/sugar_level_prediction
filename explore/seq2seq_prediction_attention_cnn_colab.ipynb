# %% [markdown]
# # Sequence to Sequence models for sugar level prediction
#
# Seq2Seq modelling with Recurrent Neural Networks,
# take a look at https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html
#
# We also try teacher-forcing training, but it does not seem to provide good results in inference.
#
# Finally, we use ConvNets for creating input features to the encoder.

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import os
import sys
import time
import copy
import tensorflow as tf

# %%
from tensorflow.keras.layers import Dense, LSTM, Input, RepeatVector, concatenate
from tensorflow.keras.layers import Embedding, GaussianNoise, Reshape, Dropout 
from tensorflow.keras.layers import Convolution1D, AveragePooling1D
from tensorflow.keras.models import Model
from tensorflow.keras.losses import MAE
from tensorflow.keras.metrics import MAPE, MSE
from tensorflow.keras.backend import clear_session
from tensorflow.keras.constraints import max_norm

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# ### Load datasets
#
# Each dataset consits of sequences of `history`+`future` points, with 4 features:
#
# * time interval: days counted starting from the end of the `history` of the sequence. Thus, for points in the `history`, this feature takes negatuve values, while for points in the `future`, it's positive.
# * hour: hour of the day, divided by 24.
# * day of week: day of the week in numbers ('Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 'Friday': 4, 'Saturday': 5, 'Sunday': 6), divided by 7.
# * sugar level: recorded sugar level, scaled with min/max scaler.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
root = "/content/drive/My Drive/Colab Notebooks/sugar_level_prediction/data/processed"
lastdate = '2020-01-22'
root = os.path.join(root, lastdate)

history = 6 * 24 * 4
future = 3 * 4

noise = 0.0
replace = False

train = np.load(os.path.join(root, "noise_%s_train_steps_%s_replace_%s.npy" %(noise, int(history)*3, replace)))
vad = np.load(os.path.join(root, "noise_%s_vad_steps_%s_replace_%s.npy" %(noise, int(history)*3, replace)))
test = np.load(os.path.join(root, "noise_%s_test_steps_%s_replace_%s.npy" %(noise, int(history)*3, replace)))

assert history+future == train.shape[1]

# %%
np.random.seed(1203)
np.random.shuffle(train)

# %% [markdown]
# ###  Split data
#
# Each input sequence has both the features and labels (x and y, if you wish), so we have to separate them.

# %%
def split_features_labels(data, history, future, start_char):
    """
    Method to separate historic and future events (features and labels). 
    It returns input data for the encoder and decoder, and the output data 
    for the decoder. The input data for the decoder is just the output data 
    of the decoder, shifted by one step. 

    :param data: numpy ndarray with sequences of history+future points, and 4 attributes 
      (time_interval, hour_of_day, day_of_week, patient_id, sugar_level). It has shape (?, history+future, 5)
    :param history: number of points for the features
    :param future: number of points for the labels
    :param start_char: start charcter for input sequences to the decoder
    :return three numpy arrays with the input data for the encoder (shape=(?, history, 5))
        and decoder (shape=(?, future+1, 1)), and the output data for the decoder
        (shape=(?, future+1, 1))
    """
    # split features and labels . Note that for the later, we only keep the 
    # feature with the sugar level, which constitutes our target
    yf, yl = data[:, :history], data[:, history:history+future, -1]
    
    # add start of sentence to labels (input to the decoder)
    yl_input = start_char * np.ones(shape=(yl.shape[0], yl.shape[1]+1))
    yl_input[:, 1:] = yl
    # add end of sentence to labels (output of the decoder)
    yl_output = start_char * np.ones(shape=(yl.shape[0], yl.shape[1]+1))
    yl_output[:, :-1] = yl
    
    # add new dimension at the end of input/output arrays to the decoder
    yl_input = yl_input[:, :, np.newaxis].astype(np.float32)
    yl_output = yl_output[:, :, np.newaxis].astype(np.float32)
    
    return (yf, yl_input), yl_output

# %%
start_char = -1.0
train_data = split_features_labels(train, history, future, start_char)
vad_data = split_features_labels(vad, history, future, start_char)
test_data = split_features_labels(test, history, future, start_char)

# %%
train_data[0][0].shape, train_data[0][1].shape, train_data[1].shape
# Out:
# ((310099, 576, 5), (310099, 13, 1), (310099, 13, 1))

# %% [markdown]
# ## Some auxiliar functions

# %%
def plot_train_history(history, title, metric):
    plt.figure(figsize=(12, 6))
    loss = history[metric]
    val_loss = history['val_%s' %metric]

    epochs = range(len(loss))

    plt.plot(epochs, loss, 'b', label='Training %s' %metric)
    plt.plot(epochs, val_loss, 'r', label='Validation %s' %metric)
    plt.title(title)
    plt.legend()
    
    plt.yscale('log')
    plt.gca().grid(axis='y', which='minor')

    plt.show()

def plot_results(dataset, prediction, history, future):
    plt.figure(figsize=(12, 6))

    # get random idx
    idx = np.random.randint(0, dataset.shape[0])

    # get intervals
    xf = dataset[idx, :history, 0]
    xl = dataset[idx, history:history+future, 0]
    
    # get sequences
    input_seq_ = dataset[idx, :history, -1]
    target_seq_ = dataset[idx, history:history+future, -1]
    decoded_seq_ = prediction[idx, :]

    ymin = input_seq_.min()-0.1
    ymax = input_seq_.max()+0.1
    
    plt.plot(xf, input_seq_, '-b', markersize=2, linewidth=2, label='historic data')
    plt.plot(xl, target_seq_, '.--b', markersize=2, linewidth=2, label='future data')
    plt.plot(xl, decoded_seq_, '.--k', markersize=2, linewidth=2, label='prediction')
    plt.vlines(x=0, ymin=ymin, ymax=ymax, colors='k', linewidth=1, linestyles='--')

    plt.ylim(ymin, ymax)
    plt.xlim(-0.3-history/4/24, future/4/24+0.3)
    
    plt.ylabel('Glucose evolution (arb.units)')
    plt.xlabel('Days before/after start prediction')
    plt.legend(loc='best')

    plt.show()

# %% [markdown]
# ## Seq2Seq model

# %% [markdown]
# ### Model

# %% [markdown]
# #### Class ProcessInput

# %%
class ProcessInput(tf.keras.Model):
  def __init__(self, dense_dim, dense_activation, gaussian_noise, num_ids,
               day_of_week_dim, hour_of_day_dim, patient_id_dim, cnn_filters, 
               list_kernel_size, pool_size, activation_cnn, mn_conv, dropout_conv,
               **kwargs):
    super(ProcessInput, self).__init__(**kwargs)

    # define attribute variables
    self.dense_dim = dense_dim
    self.dense_activation = dense_activation
    self.gaussian_noise = gaussian_noise
    self.num_ids = num_ids
    self.day_of_week_dim = day_of_week_dim 
    self.hour_of_day_dim = hour_of_day_dim 
    self.patient_id_dim = patient_id_dim
    self.cnn_filters = cnn_filters 
    self.list_kernel_size = list_kernel_size 
    self.pool_size = pool_size
    self.activation_cnn = activation_cnn 
    self.mn_conv = mn_conv
    self.dropout_conv = dropout_conv

    # Define embedding layers for Input categorical layers
    self.day_of_week_emb = Embedding(input_dim=7, output_dim=self.day_of_week_dim)
    self.hour_of_day_emb = Embedding(input_dim=24, output_dim=self.hour_of_day_dim)
    self.patient_id_emb = Embedding(input_dim=self.num_ids, output_dim=self.patient_id_dim)

    # gaussian noise layer 
    if self.gaussian_noise: 
      self.gn_layer = GaussianNoise(stddev=self.gaussian_noise)
    else: 
      self.gn_layer = None
    # dense layer
    if self.dense_dim: 
      # TODO use TimeDistributed before the Dense? I believe the layer is broadcasted here
      self.dense = Dense(self.dense_dim, activation=self.dense_activation)
    else:
        self.dense = None

  def call(self, inputs, training=False):
    # split inputs
    time_interval, hour_of_day, day_of_week, patient_id, sugar_level = inputs
    # create embeddings for categorical variables
    day_of_week = self.day_of_week_emb(day_of_week)
    hour_of_day = self.hour_of_day_emb(hour_of_day)
    patient_id = self.patient_id_emb(patient_id)

    # add noise
    if self.gn_layer:
        sugar_level = self.gn_layer(sugar_level, training=training)
    
    # Concatenate all inputs toghether, and pass them through a dense layer
    output = concatenate([time_interval, hour_of_day, day_of_week, 
                          patient_id, sugar_level], axis=-1)
    
    # generate features from CNNs. Note that num_conv_layers cannot be larger than 5
    # since we downsample by 2 in each iteration (and 24*4 is divisible by 32, but not by 64)
    for num_filters in self.cnn_filters:
        output = self.cnn_features(output, num_filters)
        output = AveragePooling1D(pool_size=self.pool_size, strides=2, padding='valid')(output)
        output = Dropout(rate=self.dropout_conv)(output, training=training)

    if self.dense:
        output = self.dense(output)
    return output

  def cnn_features(self, time_series, num_filters):
    """

    Method to extract features form a time series using Convolutional Neural Networks

    :param time_series: layer of shape=(batch_size, input_length, 1). 
        batch_size, and input_legth are not specified (set to None)
    :param num_filters: Integer, the dimensionality of the output space 
      (i.e. the number of output filters in the convolution).
    :return a layer of convolved features, of shape 
        (batch_size, input_length, filters * len(list_kernel_size))
    """
    cnn_list = []
    for kernel_size in self.list_kernel_size:
        # outputs of shape (None, input_length, filters)
        cnn = Convolution1D(filters=num_filters, kernel_size=kernel_size, strides=1, 
                            padding='same', kernel_constraint=max_norm(self.mn_conv))
        cnn = cnn(time_series)
        cnn_list.append(cnn)
    out = concatenate(cnn_list, axis=-1)
    
    return out

# %%
# simple testing
test_layer = ProcessInput(dense_dim=None, dense_activation=None, gaussian_noise=0.1, 
                          num_ids=7, day_of_week_dim=10, hour_of_day_dim=10, 
                          patient_id_dim=10, cnn_filters=[16, 32, 64], 
                          list_kernel_size=[1, 3, 5], pool_size=2, 
                          activation_cnn='elu', mn_conv=0.1, dropout_conv=0.3)

assert test_layer.dense == None
assert test_layer.gaussian_noise == 0.1
assert test_layer.gn_layer.stddev == 0.1
assert test_layer.cnn_filters == [16, 32, 64]

# check number of features after cnn
out = test_layer([Input(shape=(None, 1)), Input(shape=(None,)), Input(shape=(None,)), 
                  Input(shape=(None,)), Input(shape=(None, 1))])
num_features = test_layer.cnn_filters[-1] * len(test_layer.list_kernel_size)
assert out.get_shape().as_list() == [None, None, num_features]

# check number of temporal steps after cnn
out = test_layer([Input(shape=(128, 1)), Input(shape=(128,)), Input(shape=(128,)), 
                  Input(shape=(128,)), Input(shape=(128, 1))])
max_length = int(128 / 2**len(test_layer.cnn_filters))
assert out.get_shape().as_list() == [None, max_length, num_features]

# %% [markdown]
# #### Class Encoder

# %%
class Encoder(tf.keras.Model):
  def __init__(self, stacked_units, kernel_mn, recurrent_mn, dropout, **kwargs):
    super(Encoder, self).__init__(**kwargs)
    self.stacked_units = stacked_units
    self.kernel_mn = kernel_mn
    self.recurrent_mn = recurrent_mn
    self.dropout = dropout

    # for loop to stack lstms, with returning sequences
    self.lstms = self.stack_lstms()

  def call(self, inputs, training=False):
    for lstm in self.lstms[:-1]:
      inputs = lstm(inputs, training=training)
    encoder_outputs, state_h, state_c = self.lstms[-1](inputs ,training=training)
    encoder_states = [state_h, state_c]  
    return encoder_outputs, encoder_states

  def stack_lstms(self):
    # for loop to stack lstms, with returning sequences
    lstms = []
    for units in self.stacked_units[:-1]:
      lstm_ = LSTM(
        units, 
        return_sequences=True, 
        kernel_constraint=max_norm(self.kernel_mn),
        recurrent_constraint=max_norm(self.recurrent_mn), 
        dropout=self.dropout)
      lstms.append(lstm_)

    # the last lstm returns the states as well as the sequences
    lstm_ = LSTM(
      self.stacked_units[-1], 
      return_state=True, 
      return_sequences=True, 
      kernel_constraint=max_norm(self.kernel_mn),
      recurrent_constraint=max_norm(self.recurrent_mn), 
      dropout=self.dropout)
    lstms.append(lstm_)
    return lstms

# %%
# simple testing
input_test_layer = ProcessInput(
  dense_dim=None, dense_activation=None, gaussian_noise=0.1, 
  num_ids=7, day_of_week_dim=10, hour_of_day_dim=10, 
  patient_id_dim=10, cnn_filters=[16, 32, 64], 
  list_kernel_size=[1, 3, 5], pool_size=2, 
  activation_cnn='elu', mn_conv=0.1, dropout_conv=0.3)

input_test = input_test_layer(
  [Input(shape=(128, 1)), Input(shape=(128,)), Input(shape=(128,)), 
   Input(shape=(128,)), Input(shape=(128, 1))])

test_enc = Encoder(stacked_units=[5, 5], kernel_mn=0.3, recurrent_mn=0.1, dropout=0.3)
enc_lstms = test_enc.lstms
assert len(enc_lstms) == 2

encoder_outputs, encoder_states = test_enc(input_test)
assert len(encoder_states) == 2
max_length = int(128 / 2**len(input_test_layer.cnn_filters))
assert encoder_outputs.get_shape().as_list() == [None, max_length, 5]

# %% [markdown]
# #### Attention Layer

# %%
class BahdanauAttention(tf.keras.layers.Layer):
  def __init__(self, units, kernel_mn):
    super(BahdanauAttention, self).__init__()
    self.units = units
    self.kernel_mn = kernel_mn
    
    # Weights relating to target states (decoder typically)
    self.source_weight = tf.keras.layers.Dense(units, kernel_constraint=max_norm(kernel_mn))  
    # Weights relating to source states (encoder typically)
    self.target_weight = tf.keras.layers.Dense(units, kernel_constraint=max_norm(kernel_mn))  
    # score transformation
    self.score_weight = tf.keras.layers.Dense(1)  

  def call(self, inputs, training=False):
    # target is also referred as query, and source as values.
    target, source = inputs
    # target must be a hidden vector of shape=(None, hidden_size), 
    # while source has shape=(None, steps, hidden_size)

    # expand the dimension of the target, (None, 1, hidden_size)
    target_with_time_axis = tf.expand_dims(target, axis=1)

    # score shape == (batch_size, max_length, 1)
    # we get 1 at the last axis because we are applying score to self.V
    # the shape of the tensor before applying self.V is (batch_size, max_length, units)
    score = self.score_weight(
        tf.nn.tanh(
            self.source_weight(source) + self.target_weight(target_with_time_axis)
            )
        )

    # attention_weights shape == (batch_size, max_length, 1)
    attention_weights = tf.nn.softmax(score, axis=1)

    # context_vector shape after sum == (batch_size, hidden_size)
    context_vector = attention_weights * source
    context_vector = tf.reduce_sum(context_vector, axis=1)

    return context_vector, attention_weights

# %%
# simple testing
input_test_layer = ProcessInput(
  dense_dim=None, dense_activation=None, gaussian_noise=0.1, 
  num_ids=7, day_of_week_dim=10, hour_of_day_dim=10, 
  patient_id_dim=10, cnn_filters=[16, 32, 64, 64], 
  list_kernel_size=[1, 3, 5], pool_size=2, 
  activation_cnn='elu', mn_conv=0.1, dropout_conv=0.3)

input_test = input_test_layer(
  [Input(shape=(128, 1)), Input(shape=(128,)), Input(shape=(128,)), 
   Input(shape=(128,)), Input(shape=(128, 1))])

test_enc = Encoder(stacked_units=[5, 5], kernel_mn=0.3, recurrent_mn=0.1, dropout=0.3)
encoder_outputs, encoder_states = test_enc(input_test)
encoder_hidden = encoder_states[0]

max_length = int(128 / 2**len(input_test_layer.cnn_filters))

attention_layer = BahdanauAttention(10, kernel_mn=0.2)
attention_result, attention_weights = attention_layer([encoder_hidden, encoder_outputs])

assert attention_layer.source_weight.get_input_shape_at(0) == (None, max_length, 5)
assert attention_layer.source_weight.get_output_shape_at(0) == (None, max_length, 10)

# why this does not work?
# attention_layer.score_weight.get_output_shape_at(0)

assert attention_result.get_shape()[1] == 5
assert attention_weights.get_shape().as_list() == [None, max_length, 1]

# %% [markdown]
# #### Class decoder

# %%
class Decoder(Encoder):
  def __init__(self, stacked_units, kernel_mn, recurrent_mn, dropout, 
               mlp_units, activation_mlp, mlp_mn, use_attention, 
               attention_kernel_mn, **kwargs):
    super(Decoder, self).__init__(stacked_units, kernel_mn, recurrent_mn, dropout, **kwargs)
    self.mlp_units = mlp_units 
    self.activation_mlp = activation_mlp
    self.mlp_mn = mlp_mn
    self.use_attention = use_attention
    self.attention_kernel_mn = attention_kernel_mn

    self.mlp = self.mlp()
    if self.use_attention:
      self.attention = BahdanauAttention(units=self.stacked_units[-1], 
                                        kernel_mn=attention_kernel_mn)

  def call(self, inputs, training=False):
    # split inputs in teacher forcing input (can be None), 
    # target states (list of decoder states at t-1)
    # and source states (outputs from the encoder)
    teacher_input, target_states, source_seq = inputs
    target_state = target_states[0]
    if self.use_attention:
      context_vector, attention_weights = self.attention(inputs=[target_state, source_seq], 
                                                         training=training)
    else:
      # use the last state of the encoder
      context_vector = source_seq[:, -1, :]
      attention_weights = None
    
    # concatenate context vector and tf_input
    context_vector = tf.expand_dims(context_vector, 1)  # shape=(None, 1, dec_hidden_size)
    if teacher_input is not None:
      merged = tf.concat([context_vector, teacher_input], axis=-1)
    else:
      merged = context_vector
    
    # pass the merged vector through the stack of LSTMs
    # Initialize LSTM cell with target states at step t-1
    for lstm in self.lstms[:-1]:
      merged = lstm(merged, training=training, initial_state=target_states)
    decoder_outputs, state_h, state_c = self.lstms[-1](merged, training=training, 
                                                       initial_state=target_states)
    decoder_states = [state_h, state_c]  
    
    # reshape output, as we pass one step at a time
    decoder_outputs = tf.reshape(decoder_outputs, (-1, decoder_outputs.shape[2]))
    
    # pass the output to the mlp. output shape=(None, 1)
    out = decoder_outputs
    for dense in self.mlp:
      out = dense(out)
    return out, decoder_states, attention_weights

  def mlp(self):
    # MLP for output sequences
    mlp_stack = []
    for neurons in self.mlp_units:
        decoder_dense = Dense(neurons, activation=self.activation_mlp, 
                              kernel_constraint=max_norm(self.mlp_mn))
        mlp_stack.append(decoder_dense)
    return mlp_stack

# %%
# simple testing
input_test_layer = ProcessInput(
  dense_dim=None, dense_activation=None, gaussian_noise=0.1, 
  num_ids=7, day_of_week_dim=10, hour_of_day_dim=10, 
  patient_id_dim=10, cnn_filters=[16, 32], 
  list_kernel_size=[1, 3, 5], pool_size=2, 
  activation_cnn='elu', mn_conv=0.1, dropout_conv=0.3)

input_test = input_test_layer(
  [Input(shape=(128, 1)), Input(shape=(128,)), Input(shape=(128,)), 
   Input(shape=(128,)), Input(shape=(128, 1))])


test_enc = Encoder(stacked_units=[5, 5], kernel_mn=0.3, recurrent_mn=0.1, dropout=0.3)
encoder_outputs, encoder_states = test_enc(input_test)

max_length = int(128 / 2**len(input_test_layer.cnn_filters))

# test with teacher-forcing
test_dec = Decoder(stacked_units=[5, 5], kernel_mn=0.3, recurrent_mn=0.1, 
                   dropout=0.3, mlp_units=[4, 1], activation_mlp='relu', 
                   mlp_mn=0.4, use_attention=True, attention_kernel_mn=0.2)
input_teacher = Input(shape=(1, 1))

# initial step
input_dec = [input_teacher, encoder_states, encoder_outputs]
decoder_outputs, decoder_states, attention_weights = test_dec(input_dec)

assert len(decoder_states) == 2
assert decoder_states[0].get_shape().as_list() == [None, 5]
assert decoder_outputs.get_shape().as_list() == [None, 1]
assert attention_weights.get_shape().as_list() == [None, max_length, 1]

# subsequent steps. 
input_dec = [input_teacher, decoder_states, encoder_outputs]
decoder_outputs, decoder_states, attention_weights = test_dec(input_dec)

assert decoder_outputs.get_shape().as_list() == [None, 1]
assert attention_weights.get_shape().as_list() == [None, max_length, 1]

# Finally test without teacher-forcing
test_dec = Decoder(stacked_units=[5, 5], kernel_mn=0.3, recurrent_mn=0.1, 
                   dropout=0.3, mlp_units=[4, 1], activation_mlp='relu', 
                   mlp_mn=0.4, use_attention=True, attention_kernel_mn=0.2)
input_teacher = None

# initial step
input_dec = [input_teacher, encoder_states, encoder_outputs]
decoder_outputs, decoder_states, attention_weights = test_dec(input_dec)

assert len(decoder_states) == 2
assert decoder_states[0].get_shape().as_list() == [None, 5]
assert decoder_outputs.get_shape().as_list() == [None, 1]
assert attention_weights.get_shape().as_list() == [None, max_length, 1]

# subsequent steps. 
input_dec = [input_teacher, decoder_states, encoder_outputs]
decoder_outputs, decoder_states, attention_weights = test_dec(input_dec)
assert decoder_outputs.get_shape().as_list() == [None, 1]
assert attention_weights.get_shape().as_list() == [None, max_length, 1]

# %% [markdown]
# #### Complete model

# %%
class Seq2SeqModel(tf.keras.Model):
  def __init__(self, dense_dim, dense_activation, gaussian_noise,
               num_ids, day_of_week_dim, hour_of_day_dim, patient_id_dim,
               enc_stacked_units, enc_kernel_mn, enc_recurrent_mn,
               enc_dropout, dec_stacked_units, dec_kernel_mn, dec_recurrent_mn, 
               dec_dropout, use_attention, attention_kernel_mn, mlp_units, activation_mlp, 
               mlp_mn, teacher_forcing, start_char, learning_rate, clipvalue, 
               **kwargs):
    super(Seq2SeqModel, self).__init__(**kwargs)

    # clear worksapce
    tf.keras.backend.clear_session()

    # ProcessInput parameters
    self.dense_dim = dense_dim 
    self.dense_activation = dense_activation 
    self.gaussian_noise = gaussian_noise
    self.num_ids = num_ids 
    self.day_of_week_dim = day_of_week_dim 
    self.hour_of_day_dim = hour_of_day_dim 
    self.patient_id_dim = patient_id_dim

    # Encoder Parameters
    self.enc_stacked_units = enc_stacked_units 
    self.enc_kernel_mn = enc_kernel_mn 
    self.enc_recurrent_mn = enc_recurrent_mn
    self.enc_dropout = enc_dropout 

    # Decoder parameters
    self.dec_stacked_units = dec_stacked_units 
    self.dec_kernel_mn = dec_kernel_mn 
    self.dec_recurrent_mn = dec_recurrent_mn 
    self.dec_dropout = dec_dropout 
    self.mlp_units = mlp_units 
    self.activation_mlp = activation_mlp 
    self.mlp_mn = mlp_mn 
    self.use_attention = use_attention
    self.attention_kernel_mn = attention_kernel_mn

    # Optimization parameters
    self.learning_rate = learning_rate 
    self.clipvalue = clipvalue

    # Others
    self.teacher_forcing = teacher_forcing
    self.start_char = start_char

    # build and compile
    self.build()
    self.compile()

  def build(self):
    self.process_layer = ProcessInput(
      dense_dim=self.dense_dim, dense_activation=self.dense_activation, 
      gaussian_noise=self.gaussian_noise, num_ids=self.num_ids, 
      day_of_week_dim=self.day_of_week_dim, hour_of_day_dim=self.hour_of_day_dim, 
      patient_id_dim=self.patient_id_dim)

    self.encoder = Encoder(
      stacked_units=self.enc_stacked_units, kernel_mn=self.enc_kernel_mn, 
      recurrent_mn=self.enc_recurrent_mn, dropout=self.enc_dropout)

    self.decoder = Decoder(
      stacked_units=self.dec_stacked_units, kernel_mn=self.dec_kernel_mn, 
      recurrent_mn=self.dec_recurrent_mn, dropout=self.dec_dropout, 
      mlp_units=self.mlp_units, activation_mlp=self.activation_mlp, 
      mlp_mn=self.mlp_mn, use_attention= self.use_attention, 
      attention_kernel_mn=self.attention_kernel_mn)

  def compile(self):
    self.optimizer = tf.keras.optimizers.Adam(
      learning_rate=self.learning_rate, clipvalue=self.clipvalue)
    self.loss_function = tf.keras.losses.MeanSquaredError()
    self.metric_functions = [tf.keras.metrics.MeanAbsoluteError()]

  @tf.function
  def train_step(self, inp, tar):
    loss = 0
    
    with tf.GradientTape() as tape:
      input_enc = self.process_layer(inp, training=True)
      enc_outputs, enc_states = self.encoder(input_enc, training=True)
      dec_states = enc_states
      
      # provide start_char as first input char
      dec_input = self.start_char * tf.ones_like(tar[:, 0, :])
      
      for t in range(0, tar.shape[1]-1):
        # expand dim of dec_input
        if self.teacher_forcing:
          dec_input = tf.expand_dims(dec_input, axis=1)
        else:
          dec_input = None

        # passing enc_output to the decoder
        predictions, dec_states, _ = self.decoder(inputs=[dec_input, dec_states, enc_outputs], 
                                                  training=True)

        loss += self.loss_function(tar[:, t, :], predictions)
        _ = [m.update_state(tar[:, t, :], predictions) for m in self.metric_functions]
          
        # teacher-forcing with bernouilli distribution
        if self.teacher_forcing:
          p = tf.keras.backend.random_binomial(shape=(), p=0.9)
          dec_input = tf.keras.backend.switch(p<0.5, tar[:, t, :], predictions)
    
    batch_loss = loss / int(tar.shape[1])
    variables = self.process_layer.trainable_variables + \
      self.encoder.trainable_variables + \
      self.decoder.trainable_variables 

    gradients = tape.gradient(loss, variables)

    self.optimizer.apply_gradients(zip(gradients, variables))

    return batch_loss

  @tf.function
  def inference_step(self, inp, steps, batch_size):

    # initialize output tensor
    prediction = []

    # forward pass through process_layer and encoder
    input_enc = self.process_layer(inp, training=False)
    enc_outputs, enc_states = self.encoder(input_enc, training=False)
    dec_states = enc_states
    
    # provide start_char as first input char
    dec_input = self.start_char * tf.ones(shape=(batch_size, 1))
    
    # forward pass through the decoder
    for t in range(0, steps):
      # expand dim of dec_input
      if self.teacher_forcing:
        dec_input = tf.expand_dims(dec_input, axis=1)
      else:
        dec_input = None
      # passing enc_output to the decoder
      step_prediction, dec_states, _ = self.decoder([dec_input, dec_states, enc_outputs])
      dec_input = step_prediction
      prediction.append(tf.expand_dims(dec_input, axis=1))
    
    # concat predictions
    prediction = tf.concat(prediction, axis=1)
    
    return prediction

  def fit_custom(self, train_dataset, epochs, vad_dataset):
    history = {}
    history['loss'] = []
    history['val_loss'] = []
    for m in self.metric_functions:
      history[m.name] = []  
      history['val_%s' % (m.name)] = []  

    # steps per epoch in train and validation
    len_train = tf.data.experimental.cardinality(train_dataset).numpy()
    len_vad = tf.data.experimental.cardinality(vad_dataset).numpy()

    for epoch in range(epochs):
    
      start = time.time()
      print('Epoch ({}/{})'.format(epoch+1, epochs))
      
      pbar = tf.keras.utils.Progbar(len_train + len_vad)

      # training loop
      loop = enumerate(train_dataset.take(len_train))

      total_loss = 0

      for (batch, (inp, targ)) in loop:
        batch_loss = self.train_step(inp, targ)
        total_loss += batch_loss
        total_metric = [(m.name, m.result()) for m in self.metric_functions]
        pbar.update(batch, values=[("loss", batch_loss)] + total_metric)
      
      total_loss  /= float(len_train)
      history['loss'].append(total_loss.numpy())
      for m in self.metric_functions:
        history[m.name].append(m.result().numpy())
        m.reset_states()

      # validation loop (inference and eval)
      loop = enumerate(vad_dataset)
      
      # number of steps (we do not perform inference for the EOS)
      batch_size, steps = [(tar.shape[0], tar.shape[1]-1) for inp, tar in vad_dataset.take(1)][0]
      
      total_loss = 0
      
      for (batch, (inp, targ)) in loop:
        prediction = self.inference_step(inp, steps, batch_size)
        batch_loss = self.loss_function(prediction, targ[:, :-1, :])
        total_loss += batch_loss
        [m.update_state(targ[:, :-1, :], prediction) for m in self.metric_functions]
        total_metric = [('val_%s' %(m.name), m.result()) for m in self.metric_functions]
        pbar.update(batch, values=[("val_loss", batch_loss)] + total_metric)  
      
      total_loss  /= float(len_vad)
      history['val_loss'].append(total_loss.numpy())
      for m in self.metric_functions:
        history['val_%s' %(m.name)].append(m.result().numpy())
        m.reset_states()

      print(' ({:.0f} sec)\n'.format( time.time() - start))
    return history

  def predict_custom(self, dataset):
    start = time.time()

    # inference loop
    loop = enumerate(dataset)

    # number of steps (we do not perform inference for the EOS)
    batch_size, steps = [(tar.shape[0], tar.shape[1]-1) for inp, tar in dataset.take(1)][0]

    # num steps and progress bar    
    len_ = tf.data.experimental.cardinality(dataset).numpy()
    pbar = tf.keras.utils.Progbar(len_)

    prediction = []
    for (batch, (inp, targ)) in loop:
      # prediction has shape=(batch_size, steps, 1)
      prediction.append(self.inference_step(inp, steps, batch_size))
      pbar.update(batch)
    prediction = tf.concat(prediction, axis=0).numpy()
    print(' ({:.0f} sec)\n'.format( time.time() - start))
    return prediction

# %% [markdown]
# ### Training

# %%
def get_columns(data):
    """
    Split and prepare input data

    :param data: array with four columns: time_interval, hour_of_day, 
        day_of_week, sugar_level
    """
    time_interval, hour_of_day, day_of_week, patient_id, sugar_level = np.split(data, 
        indices_or_sections=5, axis=2)
    # squeeze categorical features (ncessary for the Embedding layer)
    hour_of_day = np.squeeze(hour_of_day, axis=2)
    day_of_week = np.squeeze(day_of_week, axis=2)
    patient_id = np.squeeze(patient_id, axis=2)
    return (time_interval, hour_of_day, day_of_week, patient_id, sugar_level)

def get_dataset(data, batch_size, shuffle=False, drop_remainder=False):
  input_ = get_columns(data[0][0])
  target_ = data[1]

  buffer_size = input_[0].shape[0]

  dataset = tf.data.Dataset.from_tensor_slices((input_, target_))
  if shuffle:
    dataset = dataset.shuffle(buffer_size)
  dataset = dataset.batch(batch_size, drop_remainder=drop_remainder)
  return dataset

# %%
batch_size = 200
steps_per_epoch = train_data[1].shape[0] // batch_size
train_dataset = get_dataset(train_data, batch_size, shuffle=True, drop_remainder=True) 
vad_dataset = get_dataset(vad_data, batch_size, shuffle=False, drop_remainder=True) 
test_dataset = get_dataset(test_data, batch_size, shuffle=False, drop_remainder=True)

# %%
num_identifiers = np.unique(train_data[0][0][:, :, 3]).size
print("There are %s individuals" % num_identifiers)
# Out:
# There are 9 individuals

# %%
standard_inputs = dict(
  # ProcessInput params
  dense_dim=80,
  dense_activation='selu',
  gaussian_noise=0.0,
  num_ids=num_identifiers,
  day_of_week_dim=20,
  hour_of_day_dim=20,
  patient_id_dim=20,
  # Encoder params
  enc_stacked_units=[128],
  enc_kernel_mn=0.1,
  enc_recurrent_mn=0.1,
  enc_dropout=0.0,
  # Decoder params
  dec_stacked_units=[128], 
  dec_kernel_mn=0.1,
  dec_recurrent_mn=0.1,
  dec_dropout=0.0,
  mlp_units=[64, 32, 8, 1],
  activation_mlp='selu',
  mlp_mn=0.3,
  use_attention=True,
  attention_kernel_mn=0.1, 
  teacher_forcing = None,
  start_char = -1.0,
  # Optimization params
  learning_rate = 5e-4,
  clipvalue = 0.5
)

# %% [markdown]
# #### Train without attention

# %%
inputs = copy.deepcopy(standard_inputs)
inputs['teacher_forcing'] = True
inputs['use_attention'] = False
inputs['dense_dim'] = None

epochs = 60

model = Seq2SeqModel(**inputs)
h = model.fit_custom(train_dataset=train_dataset, epochs=epochs, vad_dataset=vad_dataset)

plot_train_history(h, "Loss %s" %(model.loss_function), 'loss')
for metric in model.metric_functions:
  plot_train_history(h, 'Metric %s' %(metric.name), metric.name)

prediction_vad = model.predict_custom(vad_dataset)
for _ in np.arange(10):
  plot_results(vad, prediction_vad, history, future)
# Out:
# Epoch (1/60)
#  160/1712 [=>............................] - ETA: 26:08 - loss: 0.0189 - mean_absolute_error: 0.1201 - val_loss: 0.0305 - val_mean_absolute_error: 0.1399 (162 sec)
#
# Epoch (2/60)
#  160/1712 [=>............................] - ETA: 23:33 - loss: 0.0152 - mean_absolute_error: 0.0935 - val_loss: 0.0293 - val_mean_absolute_error: 0.1259 (146 sec)
#
# Epoch (3/60)
#  160/1712 [=>............................] - ETA: 23:03 - loss: 0.0147 - mean_absolute_error: 0.0906 - val_loss: 0.0279 - val_mean_absolute_error: 0.1304 (143 sec)
#
# Epoch (4/60)
#  160/1712 [=>............................] - ETA: 22:39 - loss: 0.0144 - mean_absolute_error: 0.0894 - val_loss: 0.0270 - val_mean_absolute_error: 0.1276 (140 sec)
#
# Epoch (5/60)
#  160/1712 [=>............................] - ETA: 23:12 - loss: 0.0143 - mean_absolute_error: 0.0891 - val_loss: 0.0264 - val_mean_absolute_error: 0.1241 (144 sec)
#
# Epoch (6/60)
#  160/1712 [=>............................] - ETA: 22:41 - loss: 0.0139 - mean_absolute_error: 0.0866 - val_loss: 0.0295 - val_mean_absolute_error: 0.1324 (140 sec)
#
# Epoch (7/60)
#  160/1712 [=>............................] - ETA: 22:25 - loss: 0.0143 - mean_absolute_error: 0.0896 - val_loss: 0.0262 - val_mean_absolute_error: 0.1219 (139 sec)
#
# Epoch (8/60)
#  160/1712 [=>............................] - ETA: 22:42 - loss: 0.0137 - mean_absolute_error: 0.0863 - val_loss: 0.0255 - val_mean_absolute_error: 0.1203 (141 sec)
#
# Epoch (9/60)
#  160/1712 [=>............................] - ETA: 22:35 - loss: 0.0136 - mean_absolute_error: 0.0868 - val_loss: 0.0260 - val_mean_absolute_error: 0.1185 (140 sec)
#
# Epoch (10/60)
#  160/1712 [=>............................] - ETA: 23:05 - loss: 0.0138 - mean_absolute_error: 0.0900 - val_loss: 0.0253 - val_mean_absolute_error: 0.1202 (143 sec)
#
# Epoch (11/60)
#  160/1712 [=>............................] - ETA: 23:08 - loss: 0.0135 - mean_absolute_error: 0.0851 - val_loss: 0.0264 - val_mean_absolute_error: 0.1243 (143 sec)
#
# Epoch (12/60)
#  160/1712 [=>............................] - ETA: 23:16 - loss: 0.0138 - mean_absolute_error: 0.0868 - val_loss: 0.0258 - val_mean_absolute_error: 0.1192 (144 sec)
#
# Epoch (13/60)
#  160/1712 [=>............................] - ETA: 23:08 - loss: 0.0133 - mean_absolute_error: 0.0853 - val_loss: 0.0254 - val_mean_absolute_error: 0.1183 (143 sec)
#
# Epoch (14/60)
#  160/1712 [=>............................] - ETA: 22:53 - loss: 0.0135 - mean_absolute_error: 0.0850 - val_loss: 0.0362 - val_mean_absolute_error: 0.1383 (142 sec)
#
# Epoch (15/60)
#  160/1712 [=>............................] - ETA: 22:45 - loss: 0.0135 - mean_absolute_error: 0.0847 - val_loss: 0.0281 - val_mean_absolute_error: 0.1252 (141 sec)
#
# Epoch (16/60)
#  160/1712 [=>............................] - ETA: 23:00 - loss: 0.0131 - mean_absolute_error: 0.0852 - val_loss: 0.0274 - val_mean_absolute_error: 0.1272 (142 sec)
#
# Epoch (17/60)
#  160/1712 [=>............................] - ETA: 22:52 - loss: 0.0130 - mean_absolute_error: 0.0841 - val_loss: 0.0286 - val_mean_absolute_error: 0.1208 (142 sec)
#
# Epoch (18/60)
#  160/1712 [=>............................] - ETA: 22:52 - loss: 0.0135 - mean_absolute_error: 0.0843 - val_loss: 0.0668 - val_mean_absolute_error: 0.2122 (142 sec)
#
# Epoch (19/60)
#  161/1712 [=>............................] - ETA: 22:35 - loss: 0.0128 - mean_absolute_error: 0.0828 - val_loss: 0.0387 - val_mean_absolute_error: 0.1506 (141 sec)
#
# Epoch (20/60)
#  161/1712 [=>............................] - ETA: 22:47 - loss: 0.0128 - mean_absolute_error: 0.0834 - val_loss: 0.0275 - val_mean_absolute_error: 0.1197 (142 sec)
#
# Epoch (21/60)
#  160/1712 [=>............................] - ETA: 22:54 - loss: 0.0130 - mean_absolute_error: 0.0832 - val_loss: 0.0254 - val_mean_absolute_error: 0.1182 (142 sec)
#
# Epoch (22/60)
#  160/1712 [=>............................] - ETA: 22:55 - loss: 0.0129 - mean_absolute_error: 0.0832 - val_loss: 0.0273 - val_mean_absolute_error: 0.1207 (142 sec)
#
# Epoch (23/60)
#  160/1712 [=>............................] - ETA: 22:48 - loss: 0.0128 - mean_absolute_error: 0.0818 - val_loss: 0.0248 - val_mean_absolute_error: 0.1166 (141 sec)
#
# Epoch (24/60)
#  160/1712 [=>............................] - ETA: 22:55 - loss: 0.0129 - mean_absolute_error: 0.0828 - val_loss: 0.0250 - val_mean_absolute_error: 0.1192 (142 sec)
#
# Epoch (25/60)
#  160/1712 [=>............................] - ETA: 22:47 - loss: 0.0129 - mean_absolute_error: 0.0823 - val_loss: 0.0342 - val_mean_absolute_error: 0.1470 (141 sec)
#
# Epoch (26/60)
#  160/1712 [=>............................] - ETA: 22:38 - loss: 0.0127 - mean_absolute_error: 0.0821 - val_loss: 0.0251 - val_mean_absolute_error: 0.1203 (140 sec)
#
# Epoch (27/60)
#  160/1712 [=>............................] - ETA: 22:26 - loss: 0.0125 - mean_absolute_error: 0.0808 - val_loss: 0.0274 - val_mean_absolute_error: 0.1181 (139 sec)
#
# Epoch (28/60)
#  160/1712 [=>............................] - ETA: 22:29 - loss: 0.0126 - mean_absolute_error: 0.0815 - val_loss: 0.0263 - val_mean_absolute_error: 0.1243 (139 sec)
#
# Epoch (29/60)
#  160/1712 [=>............................] - ETA: 22:27 - loss: 0.0126 - mean_absolute_error: 0.0815 - val_loss: 0.0302 - val_mean_absolute_error: 0.1357 (139 sec)
#
# Epoch (30/60)
#  160/1712 [=>............................] - ETA: 22:40 - loss: 0.0126 - mean_absolute_error: 0.0812 - val_loss: 0.0267 - val_mean_absolute_error: 0.1238 (140 sec)
#
# Epoch (31/60)
#  160/1712 [=>............................] - ETA: 22:39 - loss: 0.0127 - mean_absolute_error: 0.0813 - val_loss: 0.0248 - val_mean_absolute_error: 0.1165 (140 sec)
#
# Epoch (32/60)
#  160/1712 [=>............................] - ETA: 22:42 - loss: 0.0125 - mean_absolute_error: 0.0820 - val_loss: 0.0247 - val_mean_absolute_error: 0.1192 (141 sec)
#
# Epoch (33/60)
#  160/1712 [=>............................] - ETA: 22:25 - loss: 0.0125 - mean_absolute_error: 0.0817 - val_loss: 0.0249 - val_mean_absolute_error: 0.1164 (139 sec)
#
# Epoch (34/60)
#  160/1712 [=>............................] - ETA: 22:33 - loss: 0.0124 - mean_absolute_error: 0.0812 - val_loss: 0.0261 - val_mean_absolute_error: 0.1175 (140 sec)
#
# Epoch (35/60)
#  160/1712 [=>............................] - ETA: 22:28 - loss: 0.0126 - mean_absolute_error: 0.0816 - val_loss: 0.0254 - val_mean_absolute_error: 0.1167 (139 sec)
#
# Epoch (36/60)
#  160/1712 [=>............................] - ETA: 22:25 - loss: 0.0124 - mean_absolute_error: 0.0801 - val_loss: 0.0251 - val_mean_absolute_error: 0.1187 (139 sec)
#
# Epoch (37/60)
#  160/1712 [=>............................] - ETA: 22:37 - loss: 0.0121 - mean_absolute_error: 0.0794 - val_loss: 0.0264 - val_mean_absolute_error: 0.1200 (140 sec)
#
# Epoch (38/60)
#  160/1712 [=>............................] - ETA: 22:37 - loss: 0.0120 - mean_absolute_error: 0.0804 - val_loss: 0.0249 - val_mean_absolute_error: 0.1205 (140 sec)
#
# Epoch (39/60)
#  160/1712 [=>............................] - ETA: 22:34 - loss: 0.0127 - mean_absolute_error: 0.0815 - val_loss: 0.0269 - val_mean_absolute_error: 0.1219 (140 sec)
#
# Epoch (40/60)
#  160/1712 [=>............................] - ETA: 22:27 - loss: 0.0123 - mean_absolute_error: 0.0811 - val_loss: 0.0252 - val_mean_absolute_error: 0.1224 (139 sec)
#
# Epoch (41/60)
#  160/1712 [=>............................] - ETA: 22:21 - loss: 0.0125 - mean_absolute_error: 0.0816 - val_loss: 0.0243 - val_mean_absolute_error: 0.1179 (138 sec)
#
# Epoch (42/60)
#  160/1712 [=>............................] - ETA: 22:24 - loss: 0.0122 - mean_absolute_error: 0.0791 - val_loss: 0.0260 - val_mean_absolute_error: 0.1197 (139 sec)
#
# Epoch (43/60)
#  160/1712 [=>............................] - ETA: 22:25 - loss: 0.0123 - mean_absolute_error: 0.0803 - val_loss: 0.0308 - val_mean_absolute_error: 0.1280 (139 sec)
#
# Epoch (44/60)
#  160/1712 [=>............................] - ETA: 22:22 - loss: 0.0120 - mean_absolute_error: 0.0782 - val_loss: 0.0276 - val_mean_absolute_error: 0.1304 (138 sec)
#
# Epoch (45/60)
#  160/1712 [=>............................] - ETA: 22:14 - loss: 0.0119 - mean_absolute_error: 0.0782 - val_loss: 0.0257 - val_mean_absolute_error: 0.1164 (138 sec)
#
# Epoch (46/60)
#  160/1712 [=>............................] - ETA: 22:18 - loss: 0.0120 - mean_absolute_error: 0.0783 - val_loss: 0.0254 - val_mean_absolute_error: 0.1179 (138 sec)
#
# Epoch (47/60)
#  160/1712 [=>............................] - ETA: 22:13 - loss: 0.0121 - mean_absolute_error: 0.0799 - val_loss: 0.0312 - val_mean_absolute_error: 0.1428 (138 sec)
#
# Epoch (48/60)
#  160/1712 [=>............................] - ETA: 22:10 - loss: 0.0121 - mean_absolute_error: 0.0792 - val_loss: 0.0250 - val_mean_absolute_error: 0.1183 (137 sec)
#
# Epoch (49/60)
#  160/1712 [=>............................] - ETA: 22:18 - loss: 0.0121 - mean_absolute_error: 0.0792 - val_loss: 0.0247 - val_mean_absolute_error: 0.1183 (138 sec)
#
# Epoch (50/60)
#  161/1712 [=>............................] - ETA: 22:19 - loss: 0.0121 - mean_absolute_error: 0.0791 - val_loss: 0.0256 - val_mean_absolute_error: 0.1227 (139 sec)
#
# Epoch (51/60)
#  160/1712 [=>............................] - ETA: 22:28 - loss: 0.0121 - mean_absolute_error: 0.0797 - val_loss: 0.0262 - val_mean_absolute_error: 0.1240 (139 sec)
#
# Epoch (52/60)
#  160/1712 [=>............................] - ETA: 22:38 - loss: 0.0120 - mean_absolute_error: 0.0803 - val_loss: 0.0247 - val_mean_absolute_error: 0.1158 (140 sec)
#
# Epoch (53/60)
#  160/1712 [=>............................] - ETA: 22:46 - loss: 0.0120 - mean_absolute_error: 0.0788 - val_loss: 0.0305 - val_mean_absolute_error: 0.1263 (141 sec)
#
# Epoch (54/60)
#  160/1712 [=>............................] - ETA: 22:37 - loss: 0.0117 - mean_absolute_error: 0.0774 - val_loss: 0.0258 - val_mean_absolute_error: 0.1247 (140 sec)
#
# Epoch (55/60)
#  160/1712 [=>............................] - ETA: 22:49 - loss: 0.0122 - mean_absolute_error: 0.0784 - val_loss: 0.0247 - val_mean_absolute_error: 0.1149 (141 sec)
#
# Epoch (56/60)
#  160/1712 [=>............................] - ETA: 22:39 - loss: 0.0118 - mean_absolute_error: 0.0775 - val_loss: 0.0242 - val_mean_absolute_error: 0.1151 (140 sec)
#
# Epoch (57/60)
#  160/1712 [=>............................] - ETA: 22:38 - loss: 0.0119 - mean_absolute_error: 0.0793 - val_loss: 0.0247 - val_mean_absolute_error: 0.1184 (140 sec)
#
# Epoch (58/60)
#  160/1712 [=>............................] - ETA: 22:33 - loss: 0.0118 - mean_absolute_error: 0.0769 - val_loss: 0.0261 - val_mean_absolute_error: 0.1261 (140 sec)
#
# Epoch (59/60)
#  160/1712 [=>............................] - ETA: 22:17 - loss: 0.0120 - mean_absolute_error: 0.0789 - val_loss: 0.0240 - val_mean_absolute_error: 0.1146 (138 sec)
#
# Epoch (60/60)
#  160/1712 [=>............................] - ETA: 22:16 - loss: 0.0119 - mean_absolute_error: 0.0786 - val_loss: 0.0253 - val_mean_absolute_error: 0.1230 (138 sec)
# 160/162 [============================>.] - ETA: 0s (5 sec)

# %%
inputs = copy.deepcopy(standard_inputs)
inputs['teacher_forcing'] = False
inputs['use_attention'] = False
inputs['dense_dim'] = None

epochs = 60

model = Seq2SeqModel(**inputs)
h = model.fit_custom(train_dataset=train_dataset, epochs=epochs, vad_dataset=vad_dataset)

plot_train_history(h, "Loss %s" %(model.loss_function), 'loss')
for metric in model.metric_functions:
  plot_train_history(h, 'Metric %s' %(metric.name), metric.name)

prediction_vad = model.predict_custom(vad_dataset)
for _ in np.arange(10):
  plot_results(vad, prediction_vad, history, future)
# Out:
# Epoch (1/60)
#  160/1712 [=>............................] - ETA: 24:40 - loss: 0.0291 - mean_absolute_error: 0.1439 - val_loss: 0.0276 - val_mean_absolute_error: 0.1277 (153 sec)
#
# Epoch (2/60)
#  160/1712 [=>............................] - ETA: 21:46 - loss: 0.0257 - mean_absolute_error: 0.1251 - val_loss: 0.0266 - val_mean_absolute_error: 0.1257 (135 sec)
#
# Epoch (3/60)
#  160/1712 [=>............................] - ETA: 21:36 - loss: 0.0249 - mean_absolute_error: 0.1216 - val_loss: 0.0261 - val_mean_absolute_error: 0.1214 (134 sec)
#
# Epoch (4/60)
#  160/1712 [=>............................] - ETA: 21:37 - loss: 0.0245 - mean_absolute_error: 0.1204 - val_loss: 0.0253 - val_mean_absolute_error: 0.1193 (134 sec)
#
# Epoch (5/60)
#  160/1712 [=>............................] - ETA: 21:32 - loss: 0.0242 - mean_absolute_error: 0.1189 - val_loss: 0.0250 - val_mean_absolute_error: 0.1186 (133 sec)
#
# Epoch (6/60)
#  160/1712 [=>............................] - ETA: 21:39 - loss: 0.0239 - mean_absolute_error: 0.1182 - val_loss: 0.0249 - val_mean_absolute_error: 0.1191 (134 sec)
#
# Epoch (7/60)
#  160/1712 [=>............................] - ETA: 21:36 - loss: 0.0237 - mean_absolute_error: 0.1174 - val_loss: 0.0246 - val_mean_absolute_error: 0.1172 (134 sec)
#
# Epoch (8/60)
#  160/1712 [=>............................] - ETA: 21:33 - loss: 0.0234 - mean_absolute_error: 0.1167 - val_loss: 0.0245 - val_mean_absolute_error: 0.1180 (133 sec)
#
# Epoch (9/60)
#  160/1712 [=>............................] - ETA: 21:31 - loss: 0.0231 - mean_absolute_error: 0.1156 - val_loss: 0.0244 - val_mean_absolute_error: 0.1179 (133 sec)
#
# Epoch (10/60)
#  160/1712 [=>............................] - ETA: 21:38 - loss: 0.0229 - mean_absolute_error: 0.1151 - val_loss: 0.0248 - val_mean_absolute_error: 0.1166 (134 sec)
#
# Epoch (11/60)
#  160/1712 [=>............................] - ETA: 21:37 - loss: 0.0228 - mean_absolute_error: 0.1148 - val_loss: 0.0245 - val_mean_absolute_error: 0.1194 (134 sec)
#
# Epoch (12/60)
#  160/1712 [=>............................] - ETA: 21:41 - loss: 0.0227 - mean_absolute_error: 0.1148 - val_loss: 0.0241 - val_mean_absolute_error: 0.1176 (134 sec)
#
# Epoch (13/60)
#  160/1712 [=>............................] - ETA: 21:36 - loss: 0.0226 - mean_absolute_error: 0.1143 - val_loss: 0.0240 - val_mean_absolute_error: 0.1153 (134 sec)
#
# Epoch (14/60)
#  160/1712 [=>............................] - ETA: 21:31 - loss: 0.0225 - mean_absolute_error: 0.1140 - val_loss: 0.0244 - val_mean_absolute_error: 0.1178 (133 sec)
#
# Epoch (15/60)
#  160/1712 [=>............................] - ETA: 21:26 - loss: 0.0225 - mean_absolute_error: 0.1138 - val_loss: 0.0240 - val_mean_absolute_error: 0.1152 (133 sec)
#
# Epoch (16/60)
#  160/1712 [=>............................] - ETA: 21:26 - loss: 0.0224 - mean_absolute_error: 0.1139 - val_loss: 0.0239 - val_mean_absolute_error: 0.1142 (133 sec)
#
# Epoch (17/60)
#  160/1712 [=>............................] - ETA: 21:31 - loss: 0.0224 - mean_absolute_error: 0.1136 - val_loss: 0.0247 - val_mean_absolute_error: 0.1196 (133 sec)
#
# Epoch (18/60)
#  160/1712 [=>............................] - ETA: 21:45 - loss: 0.0223 - mean_absolute_error: 0.1135 - val_loss: 0.0238 - val_mean_absolute_error: 0.1147 (135 sec)
#
# Epoch (19/60)
#  160/1712 [=>............................] - ETA: 21:45 - loss: 0.0223 - mean_absolute_error: 0.1131 - val_loss: 0.0242 - val_mean_absolute_error: 0.1157 (135 sec)
#
# Epoch (20/60)
#  160/1712 [=>............................] - ETA: 21:41 - loss: 0.0223 - mean_absolute_error: 0.1132 - val_loss: 0.0240 - val_mean_absolute_error: 0.1160 (134 sec)
#
# Epoch (21/60)
#  161/1712 [=>............................] - ETA: 21:30 - loss: 0.0223 - mean_absolute_error: 0.1130 - val_loss: 0.0238 - val_mean_absolute_error: 0.1149 (134 sec)
#
# Epoch (22/60)
#  160/1712 [=>............................] - ETA: 21:37 - loss: 0.0222 - mean_absolute_error: 0.1128 - val_loss: 0.0240 - val_mean_absolute_error: 0.1144 (134 sec)
#
# Epoch (23/60)
#  160/1712 [=>............................] - ETA: 21:37 - loss: 0.0222 - mean_absolute_error: 0.1132 - val_loss: 0.0239 - val_mean_absolute_error: 0.1152 (134 sec)
#
# Epoch (24/60)
#  160/1712 [=>............................] - ETA: 21:28 - loss: 0.0222 - mean_absolute_error: 0.1130 - val_loss: 0.0240 - val_mean_absolute_error: 0.1152 (133 sec)
#
# Epoch (25/60)
#  160/1712 [=>............................] - ETA: 21:32 - loss: 0.0222 - mean_absolute_error: 0.1130 - val_loss: 0.0240 - val_mean_absolute_error: 0.1171 (133 sec)
#
# Epoch (26/60)
#  160/1712 [=>............................] - ETA: 21:31 - loss: 0.0221 - mean_absolute_error: 0.1129 - val_loss: 0.0243 - val_mean_absolute_error: 0.1153 (133 sec)
#
# Epoch (27/60)
#  160/1712 [=>............................] - ETA: 21:45 - loss: 0.0221 - mean_absolute_error: 0.1127 - val_loss: 0.0244 - val_mean_absolute_error: 0.1171 (135 sec)
#
# Epoch (28/60)
#  160/1712 [=>............................] - ETA: 21:44 - loss: 0.0221 - mean_absolute_error: 0.1128 - val_loss: 0.0242 - val_mean_absolute_error: 0.1166 (134 sec)
#
# Epoch (29/60)
#  160/1712 [=>............................] - ETA: 21:45 - loss: 0.0221 - mean_absolute_error: 0.1129 - val_loss: 0.0241 - val_mean_absolute_error: 0.1173 (135 sec)
#
# Epoch (30/60)
#  160/1712 [=>............................] - ETA: 21:40 - loss: 0.0221 - mean_absolute_error: 0.1130 - val_loss: 0.0243 - val_mean_absolute_error: 0.1162 (134 sec)
#
# Epoch (31/60)
#  160/1712 [=>............................] - ETA: 21:40 - loss: 0.0221 - mean_absolute_error: 0.1129 - val_loss: 0.0242 - val_mean_absolute_error: 0.1182 (134 sec)
#
# Epoch (32/60)
#  160/1712 [=>............................] - ETA: 21:42 - loss: 0.0221 - mean_absolute_error: 0.1127 - val_loss: 0.0236 - val_mean_absolute_error: 0.1139 (134 sec)
#
# Epoch (33/60)
#  160/1712 [=>............................] - ETA: 22:00 - loss: 0.0220 - mean_absolute_error: 0.1127 - val_loss: 0.0237 - val_mean_absolute_error: 0.1159 (136 sec)
#
# Epoch (34/60)
#  160/1712 [=>............................] - ETA: 22:01 - loss: 0.0220 - mean_absolute_error: 0.1125 - val_loss: 0.0241 - val_mean_absolute_error: 0.1177 (136 sec)
#
# Epoch (35/60)
#  160/1712 [=>............................] - ETA: 21:55 - loss: 0.0221 - mean_absolute_error: 0.1125 - val_loss: 0.0238 - val_mean_absolute_error: 0.1149 (136 sec)
#
# Epoch (36/60)
#  160/1712 [=>............................] - ETA: 22:04 - loss: 0.0221 - mean_absolute_error: 0.1126 - val_loss: 0.0237 - val_mean_absolute_error: 0.1142 (137 sec)
#
# Epoch (37/60)
#  160/1712 [=>............................] - ETA: 22:07 - loss: 0.0220 - mean_absolute_error: 0.1121 - val_loss: 0.0239 - val_mean_absolute_error: 0.1149 (137 sec)
#
# Epoch (38/60)
#  160/1712 [=>............................] - ETA: 22:05 - loss: 0.0220 - mean_absolute_error: 0.1124 - val_loss: 0.0236 - val_mean_absolute_error: 0.1154 (137 sec)
#
# Epoch (39/60)
#  160/1712 [=>............................] - ETA: 22:01 - loss: 0.0220 - mean_absolute_error: 0.1124 - val_loss: 0.0242 - val_mean_absolute_error: 0.1174 (136 sec)
#
# Epoch (40/60)
#  160/1712 [=>............................] - ETA: 22:04 - loss: 0.0220 - mean_absolute_error: 0.1124 - val_loss: 0.0243 - val_mean_absolute_error: 0.1166 (137 sec)
#
# Epoch (41/60)
#  160/1712 [=>............................] - ETA: 22:01 - loss: 0.0220 - mean_absolute_error: 0.1124 - val_loss: 0.0238 - val_mean_absolute_error: 0.1152 (136 sec)
#
# Epoch (42/60)
#  161/1712 [=>............................] - ETA: 21:51 - loss: 0.0220 - mean_absolute_error: 0.1126 - val_loss: 0.0236 - val_mean_absolute_error: 0.1143 (136 sec)
#
# Epoch (43/60)
#  160/1712 [=>............................] - ETA: 22:00 - loss: 0.0220 - mean_absolute_error: 0.1124 - val_loss: 0.0240 - val_mean_absolute_error: 0.1165 (136 sec)
#
# Epoch (44/60)
#  160/1712 [=>............................] - ETA: 21:57 - loss: 0.0220 - mean_absolute_error: 0.1122 - val_loss: 0.0243 - val_mean_absolute_error: 0.1146 (136 sec)
#
# Epoch (45/60)
#  161/1712 [=>............................] - ETA: 21:58 - loss: 0.0220 - mean_absolute_error: 0.1127 - val_loss: 0.0240 - val_mean_absolute_error: 0.1158 (137 sec)
#
# Epoch (46/60)
#  160/1712 [=>............................] - ETA: 22:02 - loss: 0.0219 - mean_absolute_error: 0.1120 - val_loss: 0.0244 - val_mean_absolute_error: 0.1171 (136 sec)
#
# Epoch (47/60)
#  160/1712 [=>............................] - ETA: 22:03 - loss: 0.0219 - mean_absolute_error: 0.1124 - val_loss: 0.0248 - val_mean_absolute_error: 0.1197 (137 sec)
#
# Epoch (48/60)
#  160/1712 [=>............................] - ETA: 22:04 - loss: 0.0219 - mean_absolute_error: 0.1123 - val_loss: 0.0241 - val_mean_absolute_error: 0.1147 (137 sec)
#
# Epoch (49/60)
#  160/1712 [=>............................] - ETA: 22:03 - loss: 0.0219 - mean_absolute_error: 0.1123 - val_loss: 0.0235 - val_mean_absolute_error: 0.1135 (137 sec)
#
# Epoch (50/60)
#  160/1712 [=>............................] - ETA: 22:06 - loss: 0.0219 - mean_absolute_error: 0.1121 - val_loss: 0.0238 - val_mean_absolute_error: 0.1167 (137 sec)
#
# Epoch (51/60)
#  160/1712 [=>............................] - ETA: 22:06 - loss: 0.0219 - mean_absolute_error: 0.1121 - val_loss: 0.0240 - val_mean_absolute_error: 0.1156 (137 sec)
#
# Epoch (52/60)
#  161/1712 [=>............................] - ETA: 21:52 - loss: 0.0219 - mean_absolute_error: 0.1120 - val_loss: 0.0245 - val_mean_absolute_error: 0.1180 (136 sec)
#
# Epoch (53/60)
#  160/1712 [=>............................] - ETA: 21:53 - loss: 0.0219 - mean_absolute_error: 0.1121 - val_loss: 0.0245 - val_mean_absolute_error: 0.1167 (135 sec)
#
# Epoch (54/60)
#  160/1712 [=>............................] - ETA: 21:59 - loss: 0.0219 - mean_absolute_error: 0.1120 - val_loss: 0.0235 - val_mean_absolute_error: 0.1143 (136 sec)
#
# Epoch (55/60)
#  160/1712 [=>............................] - ETA: 21:52 - loss: 0.0219 - mean_absolute_error: 0.1120 - val_loss: 0.0235 - val_mean_absolute_error: 0.1144 (135 sec)
#
# Epoch (56/60)
#  160/1712 [=>............................] - ETA: 21:56 - loss: 0.0219 - mean_absolute_error: 0.1121 - val_loss: 0.0236 - val_mean_absolute_error: 0.1144 (136 sec)
#
# Epoch (57/60)
#  160/1712 [=>............................] - ETA: 21:52 - loss: 0.0219 - mean_absolute_error: 0.1122 - val_loss: 0.0242 - val_mean_absolute_error: 0.1160 (135 sec)
#
# Epoch (58/60)
#  160/1712 [=>............................] - ETA: 21:55 - loss: 0.0218 - mean_absolute_error: 0.1121 - val_loss: 0.0238 - val_mean_absolute_error: 0.1141 (136 sec)
#
# Epoch (59/60)
#  160/1712 [=>............................] - ETA: 21:52 - loss: 0.0219 - mean_absolute_error: 0.1122 - val_loss: 0.0239 - val_mean_absolute_error: 0.1155 (135 sec)
#
# Epoch (60/60)
#  161/1712 [=>............................] - ETA: 21:34 - loss: 0.0219 - mean_absolute_error: 0.1121 - val_loss: 0.0238 - val_mean_absolute_error: 0.1162 (134 sec)
# 160/162 [============================>.] - ETA: 0s (5 sec)

# %% [markdown]
# #### Train with attention

# %%
inputs = copy.deepcopy(standard_inputs)
inputs['teacher_forcing'] = False
inputs['use_attention'] = True
inputs['dense_dim'] = None

epochs = 60

model = Seq2SeqModel(**inputs)
h = model.fit_custom(train_dataset=train_dataset, epochs=epochs, vad_dataset=vad_dataset)

plot_train_history(h, "Loss %s" %(model.loss_function), 'loss')
for metric in model.metric_functions:
  plot_train_history(h, 'Metric %s' %(metric.name), metric.name)

prediction_vad = model.predict_custom(vad_dataset)
for _ in np.arange(10):
  plot_results(vad, prediction_vad, history, future)
# Out:
# Epoch (1/60)
#  161/1712 [=>............................] - ETA: 42:08 - loss: 0.0295 - mean_absolute_error: 0.1477 - val_loss: 0.0276 - val_mean_absolute_error: 0.1295 (262 sec)
#
# Epoch (2/60)
#  161/1712 [=>............................] - ETA: 38:46 - loss: 0.0258 - mean_absolute_error: 0.1255 - val_loss: 0.0263 - val_mean_absolute_error: 0.1240 (242 sec)
#
# Epoch (3/60)
#  161/1712 [=>............................] - ETA: 38:39 - loss: 0.0249 - mean_absolute_error: 0.1225 - val_loss: 0.0260 - val_mean_absolute_error: 0.1238 (241 sec)
#
# Epoch (4/60)
#  161/1712 [=>............................] - ETA: 38:24 - loss: 0.0243 - mean_absolute_error: 0.1204 - val_loss: 0.0252 - val_mean_absolute_error: 0.1207 (239 sec)
#
# Epoch (5/60)
#  161/1712 [=>............................] - ETA: 38:11 - loss: 0.0239 - mean_absolute_error: 0.1191 - val_loss: 0.0254 - val_mean_absolute_error: 0.1200 (238 sec)
#
# Epoch (6/60)
# 1111/1712 [==================>...........] - ETA: 1:28 - loss: 0.0236 - mean_absolute_error: 0.1182

# %%
inputs = copy.deepcopy(standard_inputs)
inputs['teacher_forcing'] = True
inputs['use_attention'] = True
inputs['dense_dim'] = None

epochs = 60

model = Seq2SeqModel(**inputs)
h = model.fit_custom(train_dataset=train_dataset, epochs=epochs, vad_dataset=vad_dataset)

plot_train_history(h, "Loss %s" %(model.loss_function), 'loss')
for metric in model.metric_functions:
  plot_train_history(h, 'Metric %s' %(metric.name), metric.name)

prediction_vad = model.predict_custom(vad_dataset)
for _ in np.arange(10):
  plot_results(vad, prediction_vad, history, future)
